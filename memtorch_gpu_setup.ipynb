# %%
from google.colab import drive
import os, sys
drive.mount("/content/drive")
nb_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)  # The reason for this is to prevent pip installing again when you restart your env.
sys.path.insert(0,nb_path)

# %%
# !git clone --recursive https://github.com/coreylammie/MemTorch

# %% [markdown]
# # Edit setup.py and remove `sklearn` and change to `scikit-learn` and `CUDA` to True. Save it.

# %%
# %cd MemTorch

# %% [markdown]
# ## Takes like 20 mins or so to install

# %%
# !pip install --target=$nb_path .

# %% [markdown]
# Just to be safe. Do this command
# `cd memtorch`
# `zip -r memtorch.zip .`
#
# Download this in your computer or put it in your Google Drive where all the other packages are installed

# %%
# Run this command after the pip install to prevent pip installing all the python packages
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks")
